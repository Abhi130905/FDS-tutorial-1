# %%
from numpy import random
x=random.randint(100)
print(x)
# Out:
# 92

# %%
from numpy import random
x=random.rand(100)
print(x)
# Out:
# [3.46251557e-01 3.86073255e-02 9.20258695e-01 4.54380256e-01
#  9.18357276e-01 6.52874176e-01 5.39295423e-01 2.52251978e-04
#  7.84110115e-02 7.91428364e-01 9.25199465e-01 7.55132909e-01
#  4.70548885e-01 5.53858174e-01 3.41884734e-01 1.17689872e-01
#  8.72464790e-01 7.38128179e-01 5.61455515e-01 6.36490167e-01
#  6.70275228e-01 5.11751156e-01 7.35383341e-01 8.90273715e-01
#  4.14810452e-01 9.26463318e-02 8.07920624e-02 8.21161082e-01
#  4.22124061e-01 2.42436277e-01 9.04726270e-01 1.59441272e-01
#  1.77757453e-02 3.53224561e-01 1.20250170e-01 2.89249173e-01
#  9.71103497e-01 8.22359876e-01 3.92842859e-01 4.22804208e-02
#  4.63994981e-01 7.55106929e-01 7.56488703e-01 2.54929698e-01
#  9.91858790e-01 7.15469642e-01 9.77937685e-01 9.48541405e-01
#  2.46507529e-01 5.37824507e-01 8.25564631e-01 1.98178241e-01
#  5.37791944e-01 5.55075766e-01 1.42474952e-01 7.26944092e-01
#  7.24579934e-01 5.51891372e-01 4.04162509e-01 8.91778300e-01
#  6.94507385e-01 2.44233377e-01 1.32935455e-01 6.01711102e-01
#  4.29153290e-01 9.95878202e-01 1.78779471e-01 9.94258845e-01
#  3.44829637e-01 4.44276650e-01 2.64454440e-01 9.72116771e-01
#  3.47790654e-01 1.43272348e-01 1.28819318e-01 8.05748518e-01
#  6.17937396e-01 9.63828553e-01 9.11289801e-01 3.01175455e-01
#  4.58889789e-01 2.75464169e-01 7.72798618e-01 6.95959364e-01
#  9.24137066e-02 9.53981949e-02 8.47526391e-01 2.18562628e-01
#  4.47690799e-01 3.42926513e-01 9.07779212e-01 7.03511186e-01
#  2.94310007e-02 7.73068706e-01 7.87251025e-01 7.73401203e-01
#  9.28756885e-01 3.99719293e-01 1.97160047e-01 2.48215988e-01]

# %%
from numpy import random
x=random.choice([3,5,7,9],p=[0.1,0.3,0.6,0.0],size=(10))
print(x)
# Out:
# [7 7 5 7 3 7 7 7 7 7]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24000\1169273569.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=True)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24000\799546936.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
from numpy import random
x=random.binomial(n=100,p=0.5,size=100)
print(x)
# Out:
# [62 44 50 41 55 54 50 44 52 51 43 68 55 44 50 48 53 42 48 46 50 55 56 57
#  55 58 49 49 50 43 48 48 56 50 46 61 47 53 44 48 55 45 52 46 49 55 51 41
#  51 47 47 50 54 53 45 49 53 54 53 51 52 48 62 51 46 60 51 58 55 52 49 55
#  49 50 58 54 46 42 44 49 53 58 48 46 52 56 44 51 47 51 53 49 55 58 54 58
#  53 52 53 50]

# %%
from numpy import random
x=random.chisquare(df=2,size=(2,3))
print(x)
# Out:
# [[1.082831   0.0579201  2.49167922]
#  [2.0977135  0.19479841 0.05961677]]
